# %% [markdown]
# <a href="https://colab.research.google.com/github/profandersonvanin01/machine_learning/blob/main/1_Aula_Introdutoria_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INTRODUÇÃO

# %% [markdown]
# ## Áreas da Inteligência Artificial

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# fonte: https://asksuite.com/wp-content/uploads/areas-da-inteligencia-artificial-1024x614.png

# %% [markdown]
# # MACHINE LEARNING
#
# Machine Learning (ML) é uma importante área da Inteligência Artificial onde é possível criar algoritmos para ensinar uma determinada máquina a desempenhar tarefas. Um algoritmo de ML possibilita utilizar um conjunto de dados de entrada e com base em determinados padrões encontrados, gerar as saídas. Cada entrada desse conjunto de dados possuem suas próprias características (features), e ter um conjunto delas é o ponto inicial fundamental para qualquer algoritmo de ML.

# %% [markdown]
# Com ML é possível reconhecer e extrair padrões de um grande volume de dados, construindo dessa maneira um **Modelo de Aprendizado**. Esse aprendizado é baseado na observação de dados como: exemplos, experiência direta ou instrução. Uma vez que a máquina tenha aprendido, elas são capazes de executar tarefas complexas e dinâmicas, prever com mais precisão, reagir em situações diversas e comportar-se de forma inteligente.
#
# Podemos definir ML, portanto, como um campo de estudo que possibilita aos computadores a habilidade aprenderem **sem serem obrigatoriamente programados**. Ou seja, é uma forma de fazer melhor no futuro com base em experiências do passado.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Fonte: https://www.opencadd.com.br/wp-content/uploads/2019/09/AI-ML-DL.png

# %% [markdown]
# Os algoritmos de machine learning dividem-se de acordo com o problema que buscam resolver. Dentre eles, podemos destacar:
#
# **Classificação**: na classificação, o objetivo é identificar a qual categoria determinada imagem ou conjunto de dados pertence. Em outras palavras, escolher dentre uma lista pré-definida de possibilidades se uma imagem diz respeito à categoria gato ou cachorro, como no exemplo.
#
# **Regressão**: neste caso, procura-se estimar um valor numérico e não uma categoria ou rótulo. Pode ser utilizada para estimar a precificação de um produto, por exemplo.
#
# **Clusterização**: clusterizar nada mais é do que agrupar. Logo, o objetivo desse tipo de algoritmo é agrupar dados semelhantes. Por exemplo, consumidores que possuem o mesmo perfil ou fotos que contêm a mesma pessoa, similar ao que ocorre no Google Fotos.

# %% [markdown]
# ## Exemplos de aplicações com Machine Learning

# %% [markdown]
# - Detecção de fraudes.
# - Resultados de pesquisa na Web.
# - Anúncios em tempo real, tanto em páginas da web como em dispositivos móveis.
# - Análise de sentimento baseada em texto.
# - Pontuação de crédito e melhores ofertas.
# - Previsão de falhas em equipamento.
# - Novos modelos de precificação.
# - Detecção de invasão em uma determinada rede.
# - Reconhecimento de determinados padrões e imagens.
# - Filtragem de spams em e-mail.

# %% [markdown]
# ## Tipos de Machine Learning

# %% [markdown]
# O aprendizado de máquina é realizado basicamente de três formas: **supervisionada, não supervisionada e por reforço**.

# %% [markdown]
# ###  - SUPERVISIONADO

# %% [markdown]
# Problemas de aprendizagem supervisionados são classificados em problemas de "regressão" e "classificação". Em um problema de regressão, estamos tentando prever os resultados em uma saída contínua, o que significa que estamos a tentando mapear variáveis ​​de entrada para alguma função contínua. Em um problema de classificação, estamos tentando prever os resultados em uma saída discreta. Em outras palavras, estamos tentando mapear variáveis ​​de entrada em categorias distintas.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### - NÃO SUPERVISIONADO

# %% [markdown]
# A Aprendizagem não supervisionada, por outro lado, nos permite abordar problemas com pouca ou nenhuma idéia do que nossos resultados deve ser aparentar. Podemos derivar estrutura de dados onde nós não necessariamente saberiamos o efeito das variáveis.
# Podemos derivar essa estrutura, agrupando os dados com base em relações entre as variáveis ​​nos dados. Também pode ser usada para reduzir o número de dimensões em um conjunto de dados para concentrar somente nos atributos mais úteis, ou para detectar tendências.
#
# Nesse tipo podemos utilizar o Clustering: Dada uma coleção de 1000 pesquisas de uma universidade encontrar uma maneira de agrupar automaticamente estas pesquisas em um grupos que são de alguma forma semelhantes ou relacionadas por diferentes variáveis, tais como a frequência das palavras, frases, contagem de páginas, etc.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###  - POR REFORÇO

# %% [markdown]
# O aprendizado por reforço é semelhante ao que nós, humanos, temos quando somos crianças. "Todos nós passamos pelo reforço de aprendizado – quando você começou a engatinhar e tentou se levantar, caiu várias vezes, mas seus pais estavam ali para te erguer e ensinar", comentou Choi. É o ensinamento com base na experiência, em que a máquina deve lidar com o que errou antes e procurar a abordagem correta.

# %% [markdown]
# ## DICAS PARA USO DE TIPOS DE MACHINE LEARNING

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# fonte: https://res.cloudinary.com/practicaldev/image/fetch/s--FAPU1ZIn--/c_limit%2Cf_auto%2Cfl_progressive%2Cq_auto%2Cw_880/https://isitics.com/wp-content/uploads/2018/05/WP2-IA000000-07-1024x599.jpg

# %% [markdown]
# # OK. MAS POR ONDE COMEÇAR?

# %% [markdown]
# Existem inúmeros algoritmos que podem ser utilizados para resolver diversos tipos de problemas de regressão, classificação ou agrupamento.
# No site do scikit learn, existe um gráfico bem interessante para ajudar na escolha do melhor algoritmo para seu problema.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# fonte: https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html

# %% [markdown]
# # Etapas do Machine Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Numpy ==> https://numpy.org/
#
# Pandas ==> https://pandas.pydata.org/
#
# MatPlotLib ==> https://matplotlib.org/
#
# SciKit-Learn ==> https://scikit-learn.org/stable/

# %% [markdown]
# ## Prática
#
# Vamos começar primeiramente, carregando uma base de dados de vendas de mais de 16.500 jogos, cujo os dados dos campos incluem:
#
# - Rank - Ranking de vendas gerais
#
# - Nome - O nome dos jogos
#
# - Plataforma - Plataforma do lançamento dos jogos (ou seja, PC, PS4, etc.)
#
# - Ano - Ano de lançamento do jogo
#
# - Gênero - Gênero do jogo
#
# - Editora - Editora do jogo
#
# - NA_Sales - Vendas na América do Norte (em milhões)
#
# - EU_Sales - Vendas na Europa (em milhões)
#
# - JP_Sales - Vendas no Japão (em milhões)
#
# - Other_Sales - Vendas no resto do mundo (em milhões)
#
# - Global_Sales - Total de vendas mundiais.

# %% [markdown]
# ## 1 - Importando as Bibliotecas

# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score

# %% [markdown]
# ## 2 - Carregando a base de dados

# %%
games=pd.read_csv('https://raw.githubusercontent.com/profandersonvanin01/machine_learning/main/vgsales.csv')
games.head()
# aqui mostramos os 5 primeiros registros da tabela de games
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games
# aqui pedimos para ver toda a tabela, porém como é uma base muito grande, são mostrados os 5 primeiros e os 5 últimos registros
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
#informações mais detalhadas sobre os tipos de dados da tabela
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Vemos que 16598 é quantidade total de registros, porém, as colunas Year (Ano) e Publisher (Publicador) têm valores faltantes (NaN - Nulos)

# %%
#verificar total de valores nulos
games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# ## 3 - Limpar os Dados

# %% [markdown]
# Repare que na contagem de registros já podemos perceber que há resgistros na coluna Year que estão faltando (Total é de 16598 e em Year temos 16327, ou seja, uma diferença de 271 !) e também na coluna Publisher (58)
# Precisamos então eliminar de nossa base esses registros incorretos (com Year faltando)

# %% [markdown]
# Para os dados faltantes, podemos resolver isso de duas maneiras: remover os registros que possuem dados faltantes ou completá-los comum valor padrão. Para o nosso exemplo, vamos remover os registros com dados faltantes.

# %%
#apagar tudo que estiver vazio
games.dropna(inplace=True)

# %%
games.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
games.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# ...

# %% [markdown]
# ### Uma pequena análise dos dados

# %%
plt.figure(figsize=(10,5))
sns.countplot(games["Genre"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(20,5))
sns.countplot(games["Platform"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Gráfico de correlação
plt.figure(figsize=(10,6))
sns.heatmap(games.corr(), annot=True, fmt=".2f")
plt.show()

# %% [markdown]
# Existe uma correlação de 0,94 entre as vendas de NA e as vendas globais, então usaremos isso para regressão linear

# %% [markdown]
# A Coluna Rank não é uma fonte de informação a ser considerada. Então podemos remover essa coluna.

# %%
games.drop(columns="Rank",inplace=True)

# %%
games
# Out:
#                                                    Name Platform    Year  \
# 0                                            Wii Sports      Wii  2006.0
# 1                                     Super Mario Bros.      NES  1985.0
# 2                                        Mario Kart Wii      Wii  2008.0
# 3                                     Wii Sports Resort      Wii  2009.0
# 4                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16594                     Men in Black II: Alien Escape       GC  2003.0
# 16595  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16596                                        Know How 2       DS  2010.0
# 16597                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
#Mostrando os dados de NA_Sales x Global_Sales
x = np.array(games.loc[:,"NA_Sales"]).reshape(-1,1)
y = np.array(games.loc[:,"Global_Sales"]).reshape(-1,1)
plt.figure(figsize=(10,5))
plt.xlabel("NA Sales")
plt.ylabel("Global Sales")
plt.scatter(x,y,c="red")

# %% [markdown]
# ## 4 - Separar os dados em Treino e Teste

# %% [markdown]
# A divisão de teste e treino é uma técnica para avaliar o desempenho de um algoritmo de aprendizado de máquina.
#
# Ele pode ser usado para problemas de classificação ou regressão e pode ser usado para qualquer algoritmo de aprendizado supervisionado.
#
# O procedimento envolve pegar um conjunto de dados e dividi-lo em dois subconjuntos. O primeiro subconjunto é usado para ajustar o modelo e é referido como o conjunto de dados de treinamento. O segundo subconjunto não é usado para treinar o modelo; em vez disso, o elemento de entrada do conjunto de dados é fornecido ao modelo, então as previsões são feitas e comparadas com os valores esperados. Esse segundo conjunto de dados é chamado de conjunto de dados de teste.
#
# **Train Dataset** : Usado para ajustar o modelo de aprendizado de máquina.
#
# **Conjunto de dados de teste** : usado para avaliar o modelo de aprendizado de máquina adequado.
#
# O objetivo é estimar o desempenho do modelo de aprendizado de máquina em novos dados: dados não usados ​​para treinar o modelo.

# %% [markdown]
# Vamos utilizar uma variavel X para armazenar os valores de NA_Sales e uma y para os dados de Global_Sales

# %%
X = games.iloc[:, 5].values
y = games.iloc[:, 9].values

# %%
y
# Out:
# array([8.274e+01, 4.024e+01, 3.582e+01, ..., 1.000e-02, 1.000e-02,
#        1.000e-02])

# %%
#Treino-Teste divisão
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=8)

# %%
(X_train.shape,y_train.shape)
# Out:
# ((13032,), (13032,))

# %%
(X_test.shape,y_test.shape)
# Out:
# ((3259,), (3259,))

# %% [markdown]
# Precisamos remodelar os dados de arrays 2D longos com 1 coluna e quantas linhas forem necessárias

# %%
X_train = X_train.reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
y_train = y_train.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
X_train
# Out:
# array([[0.  ],
#        [0.1 ],
#        [0.04],
#        ...,
#        [0.29],
#        [0.06],
#        [0.  ]])

# %% [markdown]
# ## 5 - Criar o Modelo de Machine Learning

# %% [markdown]
# Nosso problema é o de criar um modelo de Machine Learning que faça uma previsão de valores numéricos com relação a quantidade de Vendas Globais (Global_sales). Como esse problema envolve a previsão de um valor numérico, então utilizaremos a técnica de **Regressão Linear** para prever um valor.

# %%
#Regressão Linear
from sklearn.linear_model import LinearRegression

#Modelo de Machine Learning para Regressão Linear
lin_reg = LinearRegression() 

#Treinamento do Modelo
lin_reg.fit(X_train, y_train)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

#Cálculo do Score de Treinamento
lin_reg_score_train = lin_reg.score(X_train, y_train)
print("Pontuação de Treino: ",lin_reg_score_train)

#Cálculo do Score de Teste
lin_reg_score_test = lin_reg.score(X_test, y_test)
print("Pontuação de Teste: ",lin_reg_score_test)
# Out:
# Pontuação de Treino:  0.8895135151439967
# Pontuação de Teste:  0.8565221600414654

# %% [markdown]
# ## 6 - Realizar Previsões

# %% [markdown]
# Agora que temos um modelo de Regressão Linear treinado, vamos inserir alguns dados que o modelo não conhece e comparar os resultados da previsão com os resultados reais.

# %%
previsoes = lin_reg.predict(X_test)

# %%
previsoes.shape
# Out:
# (3259, 1)

# %%
previsoes
# Out:
# array([[0.69272489],
#        [1.05075029],
#        [0.28099569],
#        ...,
#        [0.06618045],
#        [0.06618045],
#        [0.06618045]])

# %% [markdown]
# Mostrando graficamente os dados reais e os dados previstos pelo nosso modelo de ML

# %%
# Vamos criar uma função para plotagem
def plot_regression(classifier):

    plt.scatter(X_train, y_train,color='blue')
    plt.plot(X_train, classifier.predict(X_train), color='red')
    plt.title('(Dados de treino)')
    plt.xlabel('North America Sales')
    plt.ylabel('Global Sales')
    plt.show()

    plt.scatter(X_test, y_test,color='blue')
    plt.plot(X_train, classifier.predict(X_train), color='red')
    plt.title('(Dados de Teste)')
    plt.xlabel('North America Sales')
    plt.ylabel('Global Sales')
    plt.show()
    
plot_regression(lin_reg)
